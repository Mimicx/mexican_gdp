# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('mexican_gdp.csv', index_col="DATE", parse_dates=True,)
df.rename(columns={'MKTGDPMXA646NWDB':'MEXICO GDP'}, inplace=True)
df.head()
# Out:
#                      MEXICO GDP
# DATE
# 1960-01-01   13,040,000,000.00
# 1961-01-01   14,160,000,000.00
# 1962-01-01   15,200,000,000.00
# 1963-01-01   16,960,000,000.00
# 1964-01-01   20,080,000,000.00

# %%
df['MEXICO GDP 2'] = df['MEXICO GDP'].apply(lambda x: float(x.split()[0].replace(',', '')))

# %%
df.loc['2000':]['MEXICO GDP 2'].plot(figsize=(20,7))

# %%
# Out:
#                      MEXICO GDP  MEXICO GDP 2
# DATE
# 1960-01-01   13,040,000,000.00   1.304000e+10
# 1961-01-01   14,160,000,000.00   1.416000e+10
# 1962-01-01   15,200,000,000.00   1.520000e+10
# 1963-01-01   16,960,000,000.00   1.696000e+10
# 1964-01-01   20,080,000,000.00   2.008000e+10
